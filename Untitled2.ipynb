# %% [markdown]
# <a href="https://colab.research.google.com/github/avilapaula628-coder/Tareas/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
fruits = ["apple", "banana", "orange", "grape"]
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'grape']

# %%
# 2
numbers= [4, 8, 15, 16, 23, 42]
print(numbers[0])  # primer elemento)
# Out:
# 4

# %%
# 3
numbers= [4, 8, 15, 16, 23, 42]
print(numbers[5]) # último elemento)
# Out:
# 42

# %%
# 4
colors= ["red", "blue", "green", "yellow"]
print(colors[1], colors[2])  # segundo y tercero
# Out:
# blue green

# %%
# 5
cities= ["Oslo", "Francia", "Brujas", "New York" , "Berna"]
print(cities)
# Out:
# ['Oslo', 'Francia', 'Brujas', 'New York', 'Berna']

# %%
# 6
animals= ["dog", "cat", "rabbit", "hamster"]
print (animals)
# Out:
# ['dog', 'cat', 'rabbit', 'hamster']

# %%
# 7
animals = ["dog", "cat", "rabbit"]
animals.insert(1, "bird")
print(animals)
# Out:
# ['dog', 'bird', 'cat', 'rabbit']

# %%
# 8
numbers= [10, 20, 30, 40, 50]
numbers.remove(30)
print(numbers)
# Out:
# [10, 20, 40, 50]

# %%
# 9
letters=["a", "b", "c", "d", "e"]
letters.pop()
print(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %%
# 10
names = ["Ana", "Luis", "Maria", "Pedro"]
print("Maria" in names)
# Out:
# True

# %%
# 11
numbers = [5, 2, 9, 1, 7]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 5, 7, 9]

# %%
# 12
numbers = [5, 2, 9, 1, 7]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [9, 7, 5, 2, 1]

# %%
# 13
numbers = [3, 6, 9, 12, 15]
new_list = [num * 2 for num in numbers]
print(new_list)
# Out:
# [6, 12, 18, 24, 30]

# %%
# 14
words = ["python", "list", "exercise", "practice"]
for word in words:
    print(word)
# Out:
# python
# list
# exercise
# practice

# %%
# 15
grades = [80, 75, 90, 85, 95]
average = sum(grades) / len(grades)
print(average)
# Out:
# 85.0
