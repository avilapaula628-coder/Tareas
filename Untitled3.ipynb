# %% [markdown]
# <a href="https://colab.research.google.com/github/avilapaula628-coder/Tareas/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
]# 1
student = {
    "name": "Juan",
    "age": 20,
    "grade": "A"
}

print(student)
# Out:
# {'name': 'Juan', 'age': 20, 'grade': 'A'}

# %%
# 2
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car["brand"])
# Out:
# Toyota

# %%
# 3
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car["year"])
# Out:
# 2020

# %%
# 4
person = {"name": "Alice", "age": 25}

person["city"] = "Bogota"

print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bogota'}

# %%
# 5
person= {"name": "Alice", "age": 25, "city": "Bogotá"}

person["age"]= "26"

print(person)
# Out:
# {'name': 'Alice', 'age': '26', 'city': 'Bogotá'}

# %%
# 6
person= {"name": "Alice", "age": 25, "city": "Bogotá"}

person.pop("city")

print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %%
# 7
fruits = {"apple": 3, "banana": 5, "orange": 2}

print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %%
# 8
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits)
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %%
# 9
fruits = {"apple": 3, "banana": 5, "orange": 2}

for key, value in fruits.items():
    print(key, value)
# Out:
# apple 3
# banana 5
# orange 2

# %%
# 10
grades = {"Ana": 85, "Luis": 90, "Maria": 78}

print("Luis" in grades)
# Out:
# True

# %%
# 11
grades = {"Ana": 85, "Luis": 90, "Maria": 78}

print("Pedro" in grades)
# Out:
# False

# %%
# 12
numbers = {"a": 10, "b": 20, "c": 30}

total = sum(numbers.values())

print(total)
# Out:
# 60

# %%
# 13
inventory = {"pens": 10, "notebooks": 5, "erasers": 8}

print(len(inventory))
# Out:
# 3

# %%
# 14
countries = {"Colombia": "Bogotá", "France": "Paris", "Japan": "Tokyo"}
for key, value in countries.items():
    print(key, value)
# Out:
# Colombia Bogotá
# France Paris
# Japan Tokyo

# %%
# 15
temperatures = {"Monday": 22, "Tuesday": 24, "Wednesday": 21, "Thursday": 23}

max_temp = max(temperatures.values())

print(max_temp)
# Out:
# 24
